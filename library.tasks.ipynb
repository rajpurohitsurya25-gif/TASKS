# %%
print("hello")
# Out:
# hello

# %%
a = [1,2,34,5,58]

# %%
a
# Out:
# [1, 2, 34, 5, 58]

# %%
a.append(52)

# %%
a
# Out:
# [1, 2, 34, 5, 58, 52]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 5, 34, 52, 58]
